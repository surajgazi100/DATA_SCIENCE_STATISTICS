# %% [markdown]
# <a href="https://colab.research.google.com/github/surajgazi100/DATA_SCIENCE_STATISTICS/blob/main/Probability_Python_%40%402.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EXPRIMENTS

# %% [markdown]
# ![100.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # outcomes
# ![102.png](data:image/png;base64,...)

# %% [markdown]
# # Sample Space

# %% [markdown]
# In probability theory, the sample space (also called sample description space or possibility space) of an experiment or random trial is the set of all possible outcomes or results of that experiment. ... The elements of a sample space may be numbers, words, letters, or symbols.

# %% [markdown]
# ![104.png](data:image/png;base64,...)

# %% [markdown]
# # Probability model

# %% [markdown]
# ![111.gif](data:image/gif;base64,...)

# %% [markdown]
# # Axioms of Probability![112.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Conditional Probability![113.png](data:image/png;base64,...)
